# %%
import pandas as pd

# %%
playlist_data = pd.read_csv('./data/spotify_playlist.csv')

# %%
playlist_data.head()
# Out:
#   track_artists_16_type track_artists_14_name track_artists_16_name  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#        track_artists_0_id track_artists_7_name  track_episode track_type  \
# 0  2FgHPfRprDaylrSRVf1UlN                  NaN          False      track
# 1  0LSPREIgGMZXCuKVel7LVD                  NaN          False      track
# 2  4GN0Lj7b9RpYeFBqtIrNui                  NaN          False      track
# 3  6AiX12wXdXFoGJ2vk8zBjy                  NaN          False      track
# 4  7DX2CLnA9ajgQuNf5jqEXl                  NaN          False      track
#
#   track_artists_7_id track_artists_5_name track_artists_12_type  ...  \
# ...

# %%
playlist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Columns: 114 entries, track_artists_16_type to track_artists_6_name
# dtypes: bool(2), int64(5), object(107)
# memory usage: 894.6+ KB

# %%
list(playlist_data.columns)
# Out:
# ['track_artists_16_type',
#  'track_artists_14_name',
#  'track_artists_16_name',
#  'track_artists_0_id',
#  'track_artists_7_name',
#  'track_episode',
#  'track_type',
#  'track_artists_7_id',
#  'track_artists_5_name',
#  'track_artists_12_type',
#  'track_artists_17_href',
#  'track_artists_0_href',
#  'track_artists_18_id',
#  'track_artists_3_name',
#  'track_artists_2_href',
#  'track_artists_18_href',
#  'track_artists_11_name',
#  'track_artists_13_id',
#  'track_artists_8_type',
#  'track_artists_12_name',
#  'track_artists_11_id',
#  'track_artists_13_name',
#  'track_artists_2_type',
#  'track_artists_5_href',
#  'track_artists_8_name',
#  'track_album_release_date_precision',
#  'track_album_name',
#  'track_artists_14_id',
#  'track_artists_9_id',
#  'track_artists_16_id',
#  'track_artists_6_id',
#  'track_artists_12_href',
#  'track_artists_6_type',
#  'track_artists_9_name',
#  'track_artists_2_name',
#  'track_artists_18_name',
#  'track_track',
#  'added_at',
# ...
