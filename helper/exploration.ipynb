# %%
import pandas as pd

# %%
playlist_data = pd.read_csv('../data/spotify_playlist.csv')

# %%
playlist_data.head()
# Out:
#   track_album_artists_3_id track_album_artists_2_uri  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
#
#                               track_uri  track_track track_album_type  \
# 0  spotify:track:6UGkpZUshokRYSUuLeb2wT         True            album
# 1  spotify:track:2lU9QAmib9bOMYcynAywm6         True            album
# 2  spotify:track:15S79IQP09Olj9iMyg8u8m         True            album
# 3  spotify:track:3U1lRa56VJbOFqfWI2PTrj         True            album
# 4  spotify:track:6E2MIXNryG2WcVb9sh1I8L         True            album
#
#   added_by_type track_album_release_date_precision track_album_release_date  \
# 0          user                                day               2010-09-13
# ...

# %%
playlist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 34 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   track_album_artists_3_id            28 non-null     object
#  1   track_album_artists_2_uri           57 non-null     object
#  2   track_uri                           1020 non-null   object
#  3   track_track                         1020 non-null   bool
#  4   track_album_type                    1020 non-null   object
#  5   added_by_type                       1020 non-null   object
#  6   track_album_release_date_precision  1020 non-null   object
#  7   track_album_release_date            1020 non-null   object
#  8   track_album_artists_3_name          28 non-null     object
#  9   added_at                            1020 non-null   object
#  10  track_album_artists_1_name          1020 non-null   object
# ...

# %%
len(playlist_data['track_album_artists_1_uri'].unique().tolist())
# Out:
# ['6UGkpZUshokRYSUuLeb2wT',
#  '2lU9QAmib9bOMYcynAywm6',
#  '15S79IQP09Olj9iMyg8u8m',
#  '3U1lRa56VJbOFqfWI2PTrj',
#  '6E2MIXNryG2WcVb9sh1I8L',
#  '5XJBYtJWgfwk18RTamYnCZ',
#  '7yPeu0DTn2eWgO2FmHCks0',
#  '2SIQgKcQP0ztLtV6APZ9y8',
#  '4aIKdnn8WMoKjsQ6gdNM84',
#  '25shgGzsEnpDzJUinSLIBx',
#  '4qlt4KNC6TJcbBnZqnHsQW',
#  '2Ej4vdkwwBDyE6QfFWaXUF',
#  '2kFaEZJM9coKfesI5LOaPJ',
#  '55lcV76gPJUqAnHj3Z9xRd',
#  '4IoL5eSdPTk44UjQf0fk4m',
#  '4uq3InGtC8JKJQBIVTXnAr',
#  '4OmbwFpYB41rQZZUGGtFZZ',
#  '6SUMPX87AaMzVe3bydjT6b',
#  '3geKpJNdURFqbA8OqaR7vr',
#  '0Y61GxhLwaCYDJ2ojA7tZv',
#  '6KPbUKOkLLmorqSGuDao7k',
#  '7t2f17dqm0XBmN40FyyBMI',
#  '0zcuKrize0rRw3lLWYSyjK',
#  '4eE8jvNGHg7NXYFPt6REdW',
#  '2AdjREVHdOoPXDzUHcbe4g',
#  '4H6oskZ2jgfZyR79iozJLO',
#  '555d0iaIa173KumnrfnTXV',
#  '4zBY5xA8BjDhVVqSDMrOXm',
#  '3zugWFrbjpOdzKN9feQAUv',
#  '3SV6DPnu0v1Oj5TGYkIR63',
#  '7eyl9pJqvtm3RwKe1odx8Q',
#  '4YI0KYP59ohWbEnM4owHcI',
#  '7fp2ebX6fx7GN7yaj5I3cy',
#  '4QNSMIeCknaH5m0EM2yNTI',
# ...
